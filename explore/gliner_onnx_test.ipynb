# %%
from gliner2_onnx import GLiNER2ONNXRuntime

# %%
#destination = "search_models_v2"
model = GLiNER2ONNXRuntime.from_pretrained("lmo3/gliner2-large-v1-onnx")

model
# Out:
# Fetching 12 files: 100%|██████████| 12/12 [01:04<00:00,  5.34s/it]
# The tokenizer you are loading from '/home/kojo/.cache/huggingface/hub/models--lmo3--gliner2-large-v1-onnx/snapshots/6adb78ae8098685d239dda324cc124d948962c21' with an incorrect regex pattern: https://huggingface.co/mistralai/Mistral-Small-3.1-24B-Instruct-2503/discussions/84#69121093e8b480e709447d5e. This will lead to incorrect tokenization. You should set the `fix_mistral_regex=True` flag when loading this tokenizer to fix this issue.

# %%
entities = model.extract_entities(
    "John works at Google in Seattle",
    ["person", "organization", "location"]
)

entities
# Out:
# [Entity(text='John', label='person', start=0, end=4, score=1.0),
#  Entity(text='Google', label='organization', start=14, end=20, score=1.0),
#  Entity(text='Seattle', label='location', start=24, end=31, score=1.0)]

# %%
model.
